# %%
"""Importing library"""
import numpy as np
from PIL import Image

# %%
"""Load the normal X-ray image"""
normal_img = Image.open("normal.jpeg")
print(normal_img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1736x1416 at 0x1C7A82C63C0>

# %%
"""Convert the normal image to grayscale"""
normal_gray = normal_img.convert("L")
print(normal_gray)
# Out:
# <PIL.Image.Image image mode=L size=1736x1416 at 0x1C7A60BC500>
